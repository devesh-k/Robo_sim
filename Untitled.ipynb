# %%
import pybullet as p

try:
    client = p.connect(p.GUI)
    print("✅ GUI mode works! You should see a window.")
    p.disconnect()
except Exception as e:
    print(f"❌ GUI mode failed: {e}")
    print("You're in a headless environment (no display)")

# %%
print(3+3)
